# %% [markdown]
# # Multimodal Alzheimer's Disease Classification
# ### Fusing OASIS Clinical/Cognitive Features (Modality 1) with ResNet18 MRI Embeddings (Modality 2)
#
# **Pipeline position:** Clinical CSV (Kaggle) + MRI Embeddings (Drive, from `mri_embeddings.csv`) → **Fuse on `subject_id`** → Preprocess → Train baseline classifiers → Evaluate
#
# This notebook:
# 1. Downloads the OASIS Cross-Sectional clinical dataset directly from Kaggle.
# 2. Loads the 512-dim ResNet18 MRI embeddings CSV from Google Drive (produced by the previous embedding-extraction notebook).
# 3. Aligns `subject_id` formats between the two sources and merges on common subjects only.
# 4. Builds the final multimodal feature table and saves it as `final_multimodal_dataset.csv`.
# 5. Preprocesses (missing values → label encoding → scaling).
# 6. Trains three baseline multimodal classifiers: Logistic Regression, Random Forest, XGBoost.
# 7. Evaluates each with Accuracy, Precision, Recall, F1, Macro-F1, and a Confusion Matrix.
#
# > **Note on the target label:** the MRI-embedding pipeline already encodes a 3-class diagnostic label (`label`) that was used to train the upstream ResNet18 and is consistent with the rest of this project's pipeline (CNN → embeddings → GCN). We use that column as the **classification target** for the fused model, and keep the clinical `Group`/`CDR` columns as **input features**. This avoids mixing two different labeling schemes as the target and keeps the target consistent with the rest of your pipeline. If you'd rather predict the clinical `Group` label instead, see the commented alternative in the "Build Final Multimodal Dataset" section below.

# %% [markdown]
# ## 1. Setup: Install Packages

# %%
# !pip install -q kaggle xgboost scikit-learn pandas numpy matplotlib seaborn

# %% [markdown]
# ## 2. Kaggle Authentication
#
# Set your Kaggle API token below. You can get one from `kaggle.com/settings → API`.
# This mirrors the auth approach already used in your MRI-embedding notebook.

# %%
import os

# Replace with your own Kaggle API token (kaggle.com -> Settings -> API)
os.environ["KAGGLE_API_TOKEN"] = "KGAT_283606f7db27511d5bedbdc1c43c0695"

# %% [markdown]
# ## 3. Load Modality 1 — OASIS Cross-Sectional Clinical Dataset (Kaggle)
#
# We pull this directly from Kaggle (`jboysen/mri-and-alzheimers`, which contains
# `oasis_cross-sectional.csv`). If your account has a different/forked copy of the
# dataset, change `KAGGLE_DATASET_REF` below.

# %%
KAGGLE_DATASET_REF = "jboysen/mri-and-alzheimers"

# !kaggle datasets download -d {KAGGLE_DATASET_REF} -p /content/oasis_clinical --unzip
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/jboysen/mri-and-alzheimers
# License(s): CC0-1.0
# ...
# 100% 12.6k/12.6k [00:00<00:00, 27.0MB/s]

# %%
import glob

# Locate the cross-sectional CSV regardless of exact filename casing
candidates = glob.glob("/content/oasis_clinical/**/*cross*sectional*.csv", recursive=True)
if not candidates:
    candidates = glob.glob("/content/oasis_clinical/**/*.csv", recursive=True)

print("CSV files found:")
for c in candidates:
    print(" -", c)

CLINICAL_CSV_PATH = candidates[0]
print("\nUsing:", CLINICAL_CSV_PATH)
# Out:
# CSV files found:
#  - /content/oasis_clinical/oasis_cross-sectional.csv
#
# Using: /content/oasis_clinical/oasis_cross-sectional.csv

# %%
import pandas as pd
import numpy as np

clinical_df = pd.read_csv(CLINICAL_CSV_PATH)
print("Clinical dataset shape:", clinical_df.shape)
clinical_df.head()
# Out:
# Clinical dataset shape: (436, 12)
#               ID M/F Hand  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF  \
# 0  OAS1_0001_MR1   F    R   74   2.0  3.0  29.0  0.0  1344  0.743  1.306
# 1  OAS1_0002_MR1   F    R   55   4.0  1.0  29.0  0.0  1147  0.810  1.531
# 2  OAS1_0003_MR1   F    R   73   4.0  3.0  27.0  0.5  1454  0.708  1.207
# 3  OAS1_0004_MR1   M    R   28   NaN  NaN   NaN  NaN  1588  0.803  1.105
# 4  OAS1_0005_MR1   M    R   18   NaN  NaN   NaN  NaN  1737  0.848  1.010
#
#    Delay
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
clinical_df.info()
print()
print("Missing values per column:")
print(clinical_df.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 436 entries, 0 to 435
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      436 non-null    object
#  1   M/F     436 non-null    object
#  2   Hand    436 non-null    object
#  3   Age     436 non-null    int64
#  4   Educ    235 non-null    float64
#  5   SES     216 non-null    float64
#  6   MMSE    235 non-null    float64
#  7   CDR     235 non-null    float64
#  8   eTIV    436 non-null    int64
#  9   nWBV    436 non-null    float64
#  10  ASF     436 non-null    float64
#  11  Delay   20 non-null     float64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 41.0+ KB
#
# Missing values per column:
# ID         0
# M/F        0
# Hand       0
# Age        0
# Educ     201
# SES      220
# MMSE     201
# CDR      201
# eTIV       0
# nWBV       0
# ASF        0
# Delay    416
# dtype: int64

# %% [markdown]
# ### 3.1 Standardize Clinical Columns
#
# The Kaggle copy commonly uses columns like `ID`, `M/F`, `Educ`. We rename to the
# schema you described (`Age`, `Gender`, `EDUC`, `SES`, `MMSE`, `CDR`, `eTIV`,
# `nWBV`, `ASF`, `Group`) and align `subject_id` so it can be merged with the MRI
# embeddings.

# %%
rename_map = {
    "ID": "Subject_ID",
    "M/F": "Gender",
    "Educ": "EDUC",
    "EDUC": "EDUC",
    "SES": "SES",
    "Age": "Age",
    "MMSE": "MMSE",
    "CDR": "CDR",
    "eTIV": "eTIV",
    "nWBV": "nWBV",
    "ASF": "ASF",
}
clinical_df = clinical_df.rename(columns={k: v for k, v in rename_map.items() if k in clinical_df.columns})

# If a 'Group' column doesn't exist in this Kaggle copy, derive it from CDR
# (standard OASIS convention: CDR 0 -> Nondemented, CDR > 0 -> Demented)
if "Group" not in clinical_df.columns:
    if "CDR" in clinical_df.columns:
        def cdr_to_group(cdr):
            if pd.isna(cdr):
                return np.nan
            return "Nondemented" if cdr == 0 else "Demented"

        clinical_df["Group"] = clinical_df["CDR"].apply(cdr_to_group)
        print("Derived 'Group' column from CDR (CDR==0 -> Nondemented, else Demented).")
    else:
        print("WARNING: No 'Group' or 'CDR' column found — check the dataset schema above.")

print(clinical_df.columns.tolist())
clinical_df.head()
# Out:
# Derived 'Group' column from CDR (CDR==0 -> Nondemented, else Demented).
# ['Subject_ID', 'Gender', 'Hand', 'Age', 'EDUC', 'SES', 'MMSE', 'CDR', 'eTIV', 'nWBV', 'ASF', 'Delay', 'Group']
#       Subject_ID Gender Hand  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF  \
# 0  OAS1_0001_MR1      F    R   74   2.0  3.0  29.0  0.0  1344  0.743  1.306
# 1  OAS1_0002_MR1      F    R   55   4.0  1.0  29.0  0.0  1147  0.810  1.531
# 2  OAS1_0003_MR1      F    R   73   4.0  3.0  27.0  0.5  1454  0.708  1.207
# 3  OAS1_0004_MR1      M    R   28   NaN  NaN   NaN  NaN  1588  0.803  1.105
# 4  OAS1_0005_MR1      M    R   18   NaN  NaN   NaN  NaN  1737  0.848  1.010
#
#    Delay        Group
# 0    NaN  Nondemented
# 1    NaN  Nondemented
# 2    NaN     Demented
# 3    NaN          NaN
# 4    NaN          NaN

# %%
import re

# OASIS clinical IDs look like 'OAS1_0001_MR1'; the MRI-embedding pipeline keys
# on 'OAS1_0001'. Extract the matching subject pattern so the two modalities
# can be merged on a common key.
subject_pattern = re.compile(r"(OAS\d+_\d+)", re.IGNORECASE)

def extract_subject_id(raw_id):
    if pd.isna(raw_id):
        return None
    match = subject_pattern.search(str(raw_id))
    return match.group(1) if match else str(raw_id)

clinical_df["subject_id"] = clinical_df["Subject_ID"].apply(extract_subject_id)

print("Unique subject_ids in clinical data:", clinical_df["subject_id"].nunique())
clinical_df[["Subject_ID", "subject_id"]].head()
# Out:
# Unique subject_ids in clinical data: 416
#       Subject_ID subject_id
# 0  OAS1_0001_MR1  OAS1_0001
# 1  OAS1_0002_MR1  OAS1_0002
# 2  OAS1_0003_MR1  OAS1_0003
# 3  OAS1_0004_MR1  OAS1_0004
# 4  OAS1_0005_MR1  OAS1_0005

# %% [markdown]
# ## 4. Load Modality 2 — MRI Embeddings (Google Drive)
#
# These come from your earlier ResNet18 embedding-extraction notebook
# (`mri_embeddings.csv`: `subject_id`, `label`, `emb_0` … `emb_511`).

# %%
from google.colab import drive
drive.mount("/content/drive")

EMBEDDINGS_CSV  = "/content/drive/MyDrive/mri_embeddings.csv"

import os
print("Embeddings file exists:", os.path.exists(EMBEDDINGS_CSV))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Embeddings file exists: True

# %%
mri_df = pd.read_csv(EMBEDDINGS_CSV)
emb_cols = [c for c in mri_df.columns if c.startswith("emb_")]

print("MRI embeddings shape:", mri_df.shape)
print("Number of embedding dims:", len(emb_cols))
print("Unique subjects:", mri_df["subject_id"].nunique())
print("\nLabel distribution:")
print(mri_df["label"].value_counts())
mri_df[["subject_id", "label"] + emb_cols[:5]].head()
# Out:
# MRI embeddings shape: (347, 514)
# Number of embedding dims: 512
# Unique subjects: 347
#
# Label distribution:
# label
# Non Demented          266
# Very mild Dementia     58
# Dementia               23
# Name: count, dtype: int64
#   subject_id     label     emb_0     emb_1     emb_2     emb_3     emb_4
# 0  OAS1_0351  Dementia  2.166160  1.735637  1.416839  0.433220  0.828611
# 1  OAS1_0308  Dementia  0.638422  0.964953  0.859017  1.198233  0.738115
# 2  OAS1_0053  Dementia  1.749306  1.919430  1.905636  1.816800  0.898333
# 3  OAS1_0223  Dementia  0.814133  0.930930  1.099241  1.426746  0.522730
# 4  OAS1_0373  Dementia  0.519155  0.637669  0.420800  0.719033  0.297324

# %%
print("Missing values in embeddings:", mri_df[emb_cols].isna().sum().sum())
print("Duplicate subject_ids in MRI data:", mri_df["subject_id"].duplicated().sum())
# Out:
# Missing values in embeddings: 0
# Duplicate subject_ids in MRI data: 0

# %% [markdown]
# ## 5. Match Subjects Across Modalities
#
# Keep only subjects present in **both** the clinical dataset and the MRI
# embeddings.

# %%
clinical_ids = set(clinical_df["subject_id"].dropna())
mri_ids = set(mri_df["subject_id"].dropna())

common_ids = clinical_ids & mri_ids

print(f"Clinical subjects : {len(clinical_ids)}")
print(f"MRI subjects       : {len(mri_ids)}")
print(f"Common subjects     : {len(common_ids)}")
print(f"Clinical-only       : {len(clinical_ids - mri_ids)}")
print(f"MRI-only            : {len(mri_ids - clinical_ids)}")
# Out:
# Clinical subjects : 416
# MRI subjects       : 347
# Common subjects     : 347
# Clinical-only       : 69
# MRI-only            : 0

# %%
clinical_common = clinical_df[clinical_df["subject_id"].isin(common_ids)].copy()
mri_common = mri_df[mri_df["subject_id"].isin(common_ids)].copy()

# Guard against duplicate subject rows before merging (keep first occurrence)
clinical_common = clinical_common.drop_duplicates(subset="subject_id", keep="first")
mri_common = mri_common.drop_duplicates(subset="subject_id", keep="first")

print("Clinical (common only):", clinical_common.shape)
print("MRI (common only):     ", mri_common.shape)
# Out:
# Clinical (common only): (347, 14)
# MRI (common only):      (347, 514)

# %% [markdown]
# ## 6. Build Final Multimodal Dataset
#
# Merge both modalities on `subject_id` (inner join, since we already filtered to
# common subjects). The MRI pipeline's `label` column is used as the
# classification **target**; clinical columns (including `Group`/`CDR`) and all
# 512 embedding dimensions are used as **features**.
#
# ```python
# # Alternative: if you'd rather predict the clinical 'Group' label instead,
# # swap the TARGET_COL below to "Group" and drop/rename 'label' accordingly.
# ```

# %%
TARGET_COL = "label"   # MRI pipeline's diagnostic label (3-class, used as final target)

final_df = mri_common.merge(clinical_common, on="subject_id", how="inner")

print("Final multimodal dataset shape:", final_df.shape)
print("\nColumns:", final_df.columns.tolist()[:15], "...")
print("\nTarget distribution:")
print(final_df[TARGET_COL].value_counts())
final_df.head()
# Out:
# Final multimodal dataset shape: (347, 527)
#
# Columns: ['subject_id', 'label', 'emb_0', 'emb_1', 'emb_2', 'emb_3', 'emb_4', 'emb_5', 'emb_6', 'emb_7', 'emb_8', 'emb_9', 'emb_10', 'emb_11', 'emb_12'] ...
#
# Target distribution:
# label
# Non Demented          266
# Very mild Dementia     58
# Dementia               23
# Name: count, dtype: int64
#   subject_id     label     emb_0     emb_1     emb_2     emb_3     emb_4  \
# 0  OAS1_0351  Dementia  2.166160  1.735637  1.416839  0.433220  0.828611
# 1  OAS1_0308  Dementia  0.638422  0.964953  0.859017  1.198233  0.738115
# 2  OAS1_0053  Dementia  1.749306  1.919430  1.905636  1.816800  0.898333
# 3  OAS1_0223  Dementia  0.814133  0.930930  1.099241  1.426746  0.522730
# 4  OAS1_0373  Dementia  0.519155  0.637669  0.420800  0.719033  0.297324
#
#       emb_5     emb_6     emb_7  ...  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV  \
# 0  0.160828  1.113162  3.225832  ...   86   1.0  4.0  15.0  2.0  1512  0.665
# ...

# %% [markdown]
# ## 7. Preprocessing
#
# ### 7.1 Missing Value Handling

# %%
print("Missing values per column (top 15):")
print(final_df.isna().sum().sort_values(ascending=False).head(15))
# Out:
# Missing values per column (top 15):
# Delay      347
# SES        165
# Group      147
# CDR        147
# MMSE       147
# EDUC       147
# emb_342      0
# emb_344      0
# emb_345      0
# emb_346      0
# emb_347      0
# emb_348      0
# emb_349      0
# emb_350      0
# emb_351      0
# dtype: int64

# %%
clinical_numeric_cols = [c for c in ["Age", "EDUC", "SES", "MMSE", "CDR", "eTIV", "nWBV", "ASF"]
                          if c in final_df.columns]

# Numeric clinical columns -> median imputation
for col in clinical_numeric_cols:
    if final_df[col].isna().any():
        median_val = final_df[col].median()
        final_df[col] = final_df[col].fillna(median_val)
        print(f"Filled {col} missing values with median={median_val}")

# Categorical clinical columns -> mode imputation
categorical_cols = [c for c in ["Gender", "Hand"] if c in final_df.columns]
for col in categorical_cols:
    if final_df[col].isna().any():
        mode_val = final_df[col].mode()[0]
        final_df[col] = final_df[col].fillna(mode_val)
        print(f"Filled {col} missing values with mode={mode_val}")

# Embedding columns should have no NaNs, but guard anyway
final_df[emb_cols] = final_df[emb_cols].fillna(0)

print("\nRemaining missing values:", final_df.isna().sum().sum())
# Out:
# Filled EDUC missing values with median=3.0
# Filled SES missing values with median=2.0
# Filled MMSE missing values with median=29.0
# Filled CDR missing values with median=0.0
#
# Remaining missing values: 494

# %% [markdown]
# ### 7.2 Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

encoders = {}

# Encode Gender (categorical clinical feature)
if "Gender" in final_df.columns:
    le_gender = LabelEncoder()
    final_df["Gender_enc"] = le_gender.fit_transform(final_df["Gender"].astype(str))
    encoders["Gender"] = le_gender
    print("Gender classes:", list(le_gender.classes_))

# Encode the target label
le_target = LabelEncoder()
final_df["target_enc"] = le_target.fit_transform(final_df[TARGET_COL].astype(str))
encoders["target"] = le_target
print("Target classes:", list(le_target.classes_))

final_df[[TARGET_COL, "target_enc"]].drop_duplicates()
# Out:
# Gender classes: ['F', 'M']
# Target classes: ['Dementia', 'Non Demented', 'Very mild Dementia']
# /tmp/ipykernel_741/2587193118.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_df["Gender_enc"] = le_gender.fit_transform(final_df["Gender"].astype(str))
# /tmp/ipykernel_741/2587193118.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_df["target_enc"] = le_target.fit_transform(final_df[TARGET_COL].astype(str))
#                  label  target_enc
# 0             Dementia           0
# ...

# %% [markdown]
# ### 7.3 Feature Scaling

# %%
# --- Fix: remove CDR from features (it deterministically encodes the target) ---
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

clinical_numeric_cols = [c for c in ["Age", "EDUC", "SES", "MMSE", "eTIV", "nWBV", "ASF"]
                          if c in final_df.columns]
# NOTE: "CDR" intentionally excluded — crosstab confirmed it's a 1:1 encoding of the target label.

feature_cols = clinical_numeric_cols + (["Gender_enc"] if "Gender_enc" in final_df.columns else []) + emb_cols

X = final_df[feature_cols].copy()
y = final_df["target_enc"].copy()

scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=feature_cols, index=X.index)

print("Feature matrix shape (CDR removed):", X_scaled.shape)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

print("Train shape:", X_train.shape)
print("Test shape: ", X_test.shape)
# Out:
# Feature matrix shape (CDR removed): (347, 520)
# Train shape: (277, 520)
# Test shape:  (70, 520)

# %%
from sklearn.preprocessing import StandardScaler

feature_cols = clinical_numeric_cols + (["Gender_enc"] if "Gender_enc" in final_df.columns else []) + emb_cols

X = final_df[feature_cols].copy()
y = final_df["target_enc"].copy()

scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=feature_cols, index=X.index)

print("Feature matrix shape:", X_scaled.shape)
X_scaled.head()
# Out:
# Feature matrix shape: (347, 520)
#         Age      EDUC       SES      MMSE      eTIV      nWBV       ASF  \
# 0  1.314657 -2.142353  2.078461 -4.297361  0.198005 -2.024962 -0.306826
# 1  0.995869 -0.097246  0.886352 -4.297361 -0.493559 -1.399701  0.402143
# 2  1.195111 -2.142353  2.078461 -2.300685 -0.599474 -1.465518  0.517735
# 3  1.234960 -1.119800 -0.305757 -2.633464  1.001715 -1.399701 -1.008088
# 4  1.075566 -0.097246 -0.305757 -2.633464  1.568673 -1.580697 -1.447340
#
#    Gender_enc     emb_0     emb_1  ...   emb_502   emb_503   emb_504  \
# 0    1.238082  4.330030  2.847728  ...  4.429397  4.505575 -2.035312
# 1   -0.807701  0.853578  1.286640  ...  0.838823 -0.597694 -1.237803
# 2   -0.807701  3.381456  3.220018  ...  2.258632  1.938234 -2.058395
# 3    1.238082  1.253418  1.217724  ...  0.964350  1.151679 -1.807888
# 4   -0.807701  0.582179  0.623698  ...  0.296904  0.291082 -1.004299
#
#     emb_505   emb_506   emb_507   emb_508   emb_509   emb_510   emb_511
# ...

# %%
print("Shape:", X_scaled.shape)

print("\nTarget Distribution:")
print(y.value_counts())

print("\nColumns:", len(feature_cols))
# Out:
# Shape: (347, 520)
#
# Target Distribution:
# target_enc
# 1    266
# 2     58
# 0     23
# Name: count, dtype: int64
#
# Columns: 520

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# target_enc
# 1    212
# 2     46
# 0     19
# Name: count, dtype: int64
# target_enc
# 1    54
# 2    12
# 0     4
# Name: count, dtype: int64

# %% [markdown]
# ## 8. Save Final Multimodal Dataset
#
# Save the merged, pre-scaling dataset (raw + encoded columns) so it can be
# reused outside this notebook (e.g. by the GCN stage).

# %%
OUTPUT_PATH = f"{PROJECT_DIR}/final_multimodal_dataset.csv"

final_df.to_csv(OUTPUT_PATH, index=False)
print(f"Saved: {OUTPUT_PATH}")
print(f"Shape: {final_df.shape}")
# Out:
# Saved: /content/drive/MyDrive/alzheimer_project/final_multimodal_dataset.csv
# Shape: (347, 529)

# %%
import os
print(os.path.exists(f"{PROJECT_DIR}/final_multimodal_dataset.csv"))
# Should print: True
# Out:
# True

# %% [markdown]
# ## 9. Train/Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

print("Train shape:", X_train.shape)
print("Test shape: ", X_test.shape)
# Out:
# Train shape: (277, 520)
# Test shape:  (70, 520)

# %% [markdown]
# ## 10. Train Baseline Multimodal Models
#
# Logistic Regression, Random Forest, and XGBoost — all trained on the fused
# clinical + embedding feature matrix.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

models = {
    "Logistic Regression": LogisticRegression(max_iter=2000, random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=300, random_state=42),
    "XGBoost": XGBClassifier(
        n_estimators=300,
        random_state=42,
        eval_metric="mlogloss",
        use_label_encoder=False,
    ),
}

trained_models = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    trained_models[name] = model
    print(f"Trained: {name}")
# Out:
# Trained: Logistic Regression
# Trained: Random Forest
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [03:28:54] WARNING: /__w/xgboost/xgboost/src/learner.cc:793:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Trained: XGBoost

# %% [markdown]
# ## 11. Evaluate Models
#
# Accuracy, Precision, Recall, F1-score (weighted), Macro-F1, and Confusion
# Matrix for every model.

# %%
# --- Diagnostic: check for leakage and class balance before trusting results ---

print("Total subjects in final_df:", len(final_df))
print("Unique subject_ids:", final_df["subject_id"].nunique())
print()

# 1. Class balance — small/imbalanced test sets can fake perfect scores
print("Target class distribution (label):")
print(final_df[TARGET_COL].value_counts())
print()
print(f"Train size: {len(X_train)}, Test size: {len(X_test)}")
print("Test set class counts:")
print(y_test.value_counts())
print()

# 2. CDR vs label relationship — does CDR alone basically determine the target?
if "CDR" in final_df.columns:
    print("Crosstab: CDR vs target label")
    print(pd.crosstab(final_df["CDR"], final_df[TARGET_COL]))
    print()

# 3. Quick leakage probe — how well does CDR ALONE predict the target?
if "CDR" in final_df.columns:
    from sklearn.tree import DecisionTreeClassifier
    from sklearn.model_selection import cross_val_score

    X_cdr_only = final_df[["CDR"]].fillna(final_df["CDR"].median())
    y_full = final_df["target_enc"]

    clf = DecisionTreeClassifier(max_depth=3, random_state=42)
    scores = cross_val_score(clf, X_cdr_only, y_full, cv=5)
    print(f"CV accuracy using ONLY 'CDR' as a feature: {scores.mean():.3f} (+/- {scores.std():.3f})")
    print("If this is near 1.0, CDR is leaking the target almost perfectly.")
# Out:
# Total subjects in final_df: 347
# Unique subject_ids: 347
#
# Target class distribution (label):
# label
# Non Demented          266
# Very mild Dementia     58
# Dementia               23
# Name: count, dtype: int64
#
# Train size: 277, Test size: 70
# Test set class counts:
# target_enc
# 1    54
# 2    12
# 0     4
# Name: count, dtype: int64
#
# Crosstab: CDR vs target label
# label  Dementia  Non Demented  Very mild Dementia
# CDR
# 0.0           0           266                   0
# 0.5           0             0                  58
# 1.0          21             0                   0
# 2.0           2             0                   0
#
# CV accuracy using ONLY 'CDR' as a feature: 1.000 (+/- 0.000)
# If this is near 1.0, CDR is leaking the target almost perfectly.

# %%
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, classification_report
)
import matplotlib.pyplot as plt
import seaborn as sns

results = []

for name, model in trained_models.items():
    y_pred = model.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, average="weighted", zero_division=0)
    rec = recall_score(y_test, y_pred, average="weighted", zero_division=0)
    f1 = f1_score(y_test, y_pred, average="weighted", zero_division=0)
    macro_f1 = f1_score(y_test, y_pred, average="macro", zero_division=0)

    results.append({
        "Model": name,
        "Accuracy": acc,
        "Precision": prec,
        "Recall": rec,
        "F1-score": f1,
        "Macro-F1": macro_f1,
    })

    print(f"\n===== {name} =====")
    print(classification_report(
        y_test, y_pred,
        target_names=[str(c) for c in le_target.classes_],
        zero_division=0,
    ))

    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(5, 4))
    sns.heatmap(
        cm, annot=True, fmt="d", cmap="Blues",
        xticklabels=le_target.classes_, yticklabels=le_target.classes_
    )
    plt.title(f"Confusion Matrix — {name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.tight_layout()
    plt.show()
# Out:
# ===== Logistic Regression =====
#                     precision    recall  f1-score   support
#
#           Dementia       0.60      0.75      0.67         4
#       Non Demented       0.94      0.94      0.94        54
# Very mild Dementia       0.82      0.75      0.78        12
#
#           accuracy                           0.90        70
#          macro avg       0.79      0.81      0.80        70
#       weighted avg       0.90      0.90      0.90        70
# ===== Random Forest =====
#                     precision    recall  f1-score   support
#
#           Dementia       0.75      0.75      0.75         4
#       Non Demented       0.95      0.96      0.95        54
# Very mild Dementia       0.91      0.83      0.87        12
#
#           accuracy                           0.93        70
#          macro avg       0.87      0.85      0.86        70
#       weighted avg       0.93      0.93      0.93        70
# ===== XGBoost =====
# ...

# %% [markdown]
# ### 11.1 Model Comparison Summary

# %%
results_df = pd.DataFrame(results).sort_values("Macro-F1", ascending=False).reset_index(drop=True)
results_df
# Out:
#                  Model  Accuracy  Precision    Recall  F1-score  Macro-F1
# 0        Random Forest  0.928571   0.928052  0.928571  0.927967  0.857898
# 1              XGBoost  0.900000   0.904906  0.900000  0.901914  0.811526
# 2  Logistic Regression  0.900000   0.903117  0.900000  0.900828  0.797907

# %%
results_df.set_index("Model")[["Accuracy", "Precision", "Recall", "F1-score", "Macro-F1"]].plot(
    kind="bar", figsize=(9, 5)
)
plt.title("Baseline Multimodal Model Comparison")
plt.ylabel("Score")
plt.ylim(0, 1)
plt.xticks(rotation=0)
plt.legend(loc="lower right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 12. Summary
#
# - **Modality 1 (clinical)** was pulled directly from Kaggle and standardized to a common `subject_id` format.
# - **Modality 2 (MRI embeddings)** was loaded from `mri_embeddings.csv` in Google Drive.
# - Only subjects present in **both** modalities were kept, producing the fused `final_multimodal_dataset.csv`.
# - Three baseline classifiers were trained on the fused 520+ dimensional feature space (clinical + 512-dim embeddings).
# - Compare `results_df` above to choose the strongest baseline, and use it as your reference point before moving to the GCN stage.

# %% [markdown]
# ## 13. Extended Fusion Model Comparison
#
# The baseline comparison above (Logistic Regression, Random Forest, XGBoost) is
# expanded here to match the full model panel and evaluation suite used in the
# Clinical ML notebook (`OASIS_Baseline_Models.ipynb`). This section **reuses**
# the fused feature matrix and split already built above (`X_train`, `X_test`,
# `y_train`, `y_test`, `le_target`) — nothing in the fusion pipeline itself is
# changed.
#
# The fused target is **3-class** (`Non Demented` / `Very mild Dementia` /
# `Dementia`), so metrics that are normally defined for binary problems
# (Sensitivity, Specificity, NPV, AUROC, AUPRC) are computed **per class and
# macro-averaged**, which is the standard multiclass extension of the metric
# suite used in the Clinical ML notebook.

# %%
import sys
# !{sys.executable} -m pip install -q lightgbm catboost
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 9.1 MB/s eta 0:00:00

# %% [markdown]
# ### 13.1 Imports & Multiclass Evaluation Helpers

# %%
import time
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier, VotingClassifier, StackingClassifier
from sklearn.neural_network import MLPClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

from sklearn.preprocessing import label_binarize
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, confusion_matrix,
    balanced_accuracy_score, matthews_corrcoef, multilabel_confusion_matrix,
    roc_auc_score, average_precision_score, log_loss, roc_curve, precision_recall_curve
)

# Class bookkeeping — reuses the label encoder fit earlier in the notebook
FUSION_CLASSES = le_target.classes_
FUSION_N_CLASSES = len(FUSION_CLASSES)
y_test_onehot = label_binarize(y_test, classes=list(range(FUSION_N_CLASSES)))

print("Fusion target classes:", list(FUSION_CLASSES))
# Out:
# Fusion target classes: ['Dementia', 'Non Demented', 'Very mild Dementia']

# %%
def macro_specificity_npv(y_true, y_pred, n_classes):
    """Per-class Specificity / NPV (one-vs-rest) via multilabel confusion
    matrices, macro-averaged across classes."""
    mcm = multilabel_confusion_matrix(y_true, y_pred, labels=list(range(n_classes)))
    specs, npvs = [], []
    for tn, fp, fn, tp in (m.ravel() for m in mcm):
        specs.append(tn / (tn + fp) if (tn + fp) else np.nan)
        npvs.append(tn / (tn + fn) if (tn + fn) else np.nan)
    return float(np.nanmean(specs)), float(np.nanmean(npvs))


def multiclass_brier_score(y_true_onehot, y_proba):
    """Mean squared error between one-hot targets and predicted class
    probabilities, averaged over samples (multiclass Brier score)."""
    return float(np.mean(np.sum((y_proba - y_true_onehot) ** 2, axis=1)))


def top1_expected_calibration_error(correct, confidence, n_bins=10):
    """ECE computed on top-1 confidence vs. top-1 correctness — the standard
    multiclass extension of binary ECE."""
    bins = np.linspace(0.0, 1.0, n_bins + 1)
    bin_ids = np.clip(np.digitize(confidence, bins) - 1, 0, n_bins - 1)
    n = len(correct)
    ece = 0.0
    for b in range(n_bins):
        mask = bin_ids == b
        if mask.sum() == 0:
            continue
        acc = np.mean(correct[mask])
        conf = np.mean(confidence[mask])
        ece += (mask.sum() / n) * abs(acc - conf)
    return float(ece)


def top1_calibration_slope(correct, confidence):
    """Slope of a logistic regression of top-1 correctness on
    logit(top-1 confidence); 1.0 = well-calibrated."""
    eps = 1e-6
    p = np.clip(confidence, eps, 1 - eps)
    logit = np.log(p / (1 - p)).reshape(-1, 1)
    lr_cal = LogisticRegression()
    lr_cal.fit(logit, correct)
    return float(lr_cal.coef_[0][0])


# Running stores populated by every "train + evaluate" call below
fusion_table1a_rows = []
fusion_table1b_rows = []
fusion_fitted_models = {}
fusion_y_preds = {}
fusion_y_probas = {}


def fusion_train_and_evaluate(name, model, X_tr=X_train, y_tr=y_train, X_te=X_test, y_te=y_test):
    """Fit `model` on the fused feature matrix, score it on the held-out test
    set with the full multiclass metric suite, and append rows to
    Table 1A (discrimination) / Table 1B (calibration & timing)."""
    y_te_arr = np.asarray(y_te)

    t0 = time.time()
    model.fit(X_tr, y_tr)
    train_time = time.time() - t0

    t0 = time.time()
    y_pred = np.asarray(model.predict(X_te)).reshape(-1)  # CatBoost returns (n,1), not (n,)
    y_proba = model.predict_proba(X_te)
    inference_time = time.time() - t0

    specificity, npv = macro_specificity_npv(y_te_arr, y_pred, FUSION_N_CLASSES)
    confidence = y_proba.max(axis=1)
    correct = (y_pred == y_te_arr).astype(int)

    fusion_table1a_rows.append({
        "Model": name,
        "Accuracy": accuracy_score(y_te_arr, y_pred),
        "Balanced Accuracy": balanced_accuracy_score(y_te_arr, y_pred),
        "Sensitivity": recall_score(y_te_arr, y_pred, average="macro", zero_division=0),
        "Specificity": specificity,
        "Precision": precision_score(y_te_arr, y_pred, average="macro", zero_division=0),
        "NPV": npv,
        "Macro F1": f1_score(y_te_arr, y_pred, average="macro", zero_division=0),
        "MCC": matthews_corrcoef(y_te_arr, y_pred),
        "AUROC": roc_auc_score(y_te_arr, y_proba, multi_class="ovr", average="macro"),
        "AUPRC": average_precision_score(y_test_onehot, y_proba, average="macro"),
    })
    fusion_table1b_rows.append({
        "Model": name,
        "Brier Score": multiclass_brier_score(y_test_onehot, y_proba),
        "Log Loss": log_loss(y_te_arr, y_proba, labels=list(range(FUSION_N_CLASSES))),
        "ECE": top1_expected_calibration_error(correct, confidence),
        "Calibration Slope": top1_calibration_slope(correct, confidence),
        "Training Time": train_time,
        "Inference Time": inference_time,
    })

    fusion_fitted_models[name] = model
    fusion_y_preds[name] = y_pred
    fusion_y_probas[name] = y_proba
    return model

# %% [markdown]
# ### 13.2 Model Panel

# %%
fusion_models = {
    "Logistic Regression": LogisticRegression(max_iter=2000, random_state=42),
    "Linear SVM": SVC(kernel="linear", probability=True, random_state=42),
    "RBF SVM": SVC(kernel="rbf", probability=True, random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=300, random_state=42),
    "Extra Trees": ExtraTreesClassifier(n_estimators=300, random_state=42),
    "XGBoost": XGBClassifier(n_estimators=300, random_state=42, eval_metric="mlogloss"),
    "LightGBM": LGBMClassifier(n_estimators=300, random_state=42, verbosity=-1),
    "CatBoost": CatBoostClassifier(n_estimators=300, random_state=42, verbose=0),
    "MLP": MLPClassifier(random_state=42, max_iter=1000),
}

for name, model in fusion_models.items():
    fusion_train_and_evaluate(name, model)
    print(f"Trained: {name}")
# Out:
# Trained: Logistic Regression
# Trained: Linear SVM
# Trained: RBF SVM
# Trained: Decision Tree
# Trained: Random Forest
# Trained: Extra Trees
# Trained: XGBoost
# Trained: LightGBM
# Trained: CatBoost
# Trained: MLP

# %% [markdown]
# ### 13.3 Voting, Stacking & Hybrid Stacking Ensembles

# %%
voting_clf = VotingClassifier(
    estimators=[
        ("rf", RandomForestClassifier(n_estimators=300, random_state=42)),
        ("xgb", XGBClassifier(n_estimators=300, random_state=42, eval_metric="mlogloss")),
        ("lgbm", LGBMClassifier(n_estimators=300, random_state=42, verbosity=-1)),
    ],
    voting="soft",
)
fusion_train_and_evaluate("Voting Classifier", voting_clf)

stacking_clf = StackingClassifier(
    estimators=[
        ("rf", RandomForestClassifier(n_estimators=200, random_state=42)),
        ("xgb", XGBClassifier(n_estimators=200, random_state=42, eval_metric="mlogloss")),
        ("lgbm", LGBMClassifier(n_estimators=200, random_state=42, verbosity=-1)),
    ],
    final_estimator=LogisticRegression(max_iter=2000, random_state=42),
    cv=5,
    passthrough=False,
    n_jobs=-1,
)
fusion_train_and_evaluate("Stacking Classifier", stacking_clf)

hybrid_stacking_ensemble = StackingClassifier(
    estimators=[
        ("rf", RandomForestClassifier(n_estimators=200, random_state=42)),
        ("et", ExtraTreesClassifier(n_estimators=200, random_state=42)),
        ("cat", CatBoostClassifier(n_estimators=200, random_state=42, verbose=0)),
        ("xgb", XGBClassifier(n_estimators=200, random_state=42, eval_metric="mlogloss")),
    ],
    final_estimator=LogisticRegression(max_iter=2000, random_state=42),
    cv=5,
    passthrough=False,
    n_jobs=-1,
)
fusion_train_and_evaluate("Hybrid Stacking Ensemble", hybrid_stacking_ensemble)

print("Trained: Voting Classifier, Stacking Classifier, Hybrid Stacking Ensemble")
# Out:
# Trained: Voting Classifier, Stacking Classifier, Hybrid Stacking Ensemble

# %% [markdown]
# ## 14. Table 1A — Fusion Model Comparison (Discrimination Metrics)

# %%
fusion_table1a = pd.DataFrame(fusion_table1a_rows).set_index("Model").round(3)
fusion_table1a = fusion_table1a.sort_values("Macro F1", ascending=False)

best_fusion_model = fusion_table1a.index[0]
print("Best fusion model by Macro F1:", best_fusion_model)

def _highlight_best(row):
    style = "background-color: #d4f4dd; font-weight: bold"
    return [style if row.name == best_fusion_model else "" for _ in row]

fusion_table1a.style.apply(_highlight_best, axis=1).format("{:.3f}")
# Out:
# Best fusion model by Macro F1: RBF SVM
# <style type="text/css">
# #T_43f48_row0_col0, #T_43f48_row0_col1, #T_43f48_row0_col2, #T_43f48_row0_col3, #T_43f48_row0_col4, #T_43f48_row0_col5, #T_43f48_row0_col6, #T_43f48_row0_col7, #T_43f48_row0_col8, #T_43f48_row0_col9 {
#   background-color: #d4f4dd;
#   font-weight: bold;
# }
# </style>
# <table id="T_43f48" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43f48_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_43f48_level0_col1" class="col_heading level0 col1" >Balanced Accuracy</th>
#       <th id="T_43f48_level0_col2" class="col_heading level0 col2" >Sensitivity</th>
#       <th id="T_43f48_level0_col3" class="col_heading level0 col3" >Specificity</th>
#       <th id="T_43f48_level0_col4" class="col_heading level0 col4" >Precision</th>
#       <th id="T_43f48_level0_col5" class="col_heading level0 col5" >NPV</th>
# ...

# %% [markdown]
# ## 15. Table 1B — Calibration & Timing

# %%
fusion_table1b = pd.DataFrame(fusion_table1b_rows).set_index("Model").round(4)
fusion_table1b = fusion_table1b.loc[fusion_table1a.index]  # match Table 1A ordering
fusion_table1b
# Out:
#                           Brier Score  Log Loss     ECE  Calibration Slope  \
# Model
# RBF SVM                        0.1068    0.2125  0.0419             0.7548
# MLP                            0.1334    0.3243  0.0661             0.5108
# Random Forest                  0.1189    0.2069  0.0712             0.7865
# Extra Trees                    0.1141    0.1965  0.0501             0.7765
# Voting Classifier              0.1237    0.2145  0.0646             0.7056
# CatBoost                       0.1165    0.2279  0.0479             0.5852
# Stacking Classifier            0.1326    0.2628  0.0422             0.9608
# Hybrid Stacking Ensemble       0.1330    0.2480  0.0585             0.9809
# Linear SVM                     0.1128    0.1995  0.0902             1.4679
# Decision Tree                  0.2000    3.6044  0.1000            -0.0007
# XGBoost                        0.1288    0.2235  0.0668             1.0525
# ...

# %% [markdown]
# ## 16. Visualizations

# %% [markdown]
# ### 16.1 ROC Curves — Top 3 Fusion Models (macro-averaged, one-vs-rest)

# %%
fusion_top3 = fusion_table1a.head(3).index.tolist()
print("Top 3 fusion models by Macro F1:", fusion_top3)

fig, ax = plt.subplots(figsize=(7, 7))
for name in fusion_top3:
    y_proba = fusion_y_probas[name]
    fpr_grid = np.linspace(0, 1, 200)
    tpr_interp = []
    for c in range(FUSION_N_CLASSES):
        fpr_c, tpr_c, _ = roc_curve(y_test_onehot[:, c], y_proba[:, c])
        tpr_interp.append(np.interp(fpr_grid, fpr_c, tpr_c))
    mean_tpr = np.mean(tpr_interp, axis=0)
    ax.plot(fpr_grid, mean_tpr, linewidth=2.2,
            label=f"{name} (macro AUROC = {fusion_table1a.loc[name, 'AUROC']:.3f})")

ax.plot([0, 1], [0, 1], linestyle="--", color="gray", linewidth=1.2, label="Random Chance")
ax.set_xlabel("False Positive Rate")
ax.set_ylabel("True Positive Rate")
ax.set_title("ROC Curves — Top 3 Fusion Models (Macro-Averaged OvR)")
ax.legend(loc="lower right")
plt.tight_layout()
plt.show()
# Out:
# Top 3 fusion models by Macro F1: ['RBF SVM', 'MLP', 'Random Forest']

# %% [markdown]
# ### 16.2 Precision-Recall Curves — Top 3 Fusion Models (macro-averaged, one-vs-rest)

# %%
fig, ax = plt.subplots(figsize=(7, 7))
for name in fusion_top3:
    y_proba = fusion_y_probas[name]
    recall_grid = np.linspace(0, 1, 200)
    prec_interp = []
    for c in range(FUSION_N_CLASSES):
        prec_c, rec_c, _ = precision_recall_curve(y_test_onehot[:, c], y_proba[:, c])
        order = np.argsort(rec_c)  # sklearn returns recall descending; sort for interpolation
        prec_interp.append(np.interp(recall_grid, rec_c[order], prec_c[order]))
    mean_prec = np.mean(prec_interp, axis=0)
    ax.plot(recall_grid, mean_prec, linewidth=2.2,
            label=f"{name} (macro AUPRC = {fusion_table1a.loc[name, 'AUPRC']:.3f})")

class_prevalence = y_test_onehot.mean(axis=0).mean()
ax.axhline(class_prevalence, linestyle="--", color="gray", linewidth=1.2, label="Prevalence Baseline")
ax.set_xlabel("Recall")
ax.set_ylabel("Precision")
ax.set_title("Precision-Recall Curves — Top 3 Fusion Models (Macro-Averaged OvR)")
ax.legend(loc="lower left")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 16.3 Confusion Matrices — Top 3 Fusion Models

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, name in zip(axes, fusion_top3):
    cm = confusion_matrix(y_test, fusion_y_preds[name])
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
                xticklabels=FUSION_CLASSES, yticklabels=FUSION_CLASSES, ax=ax)
    ax.set_title(name)
    ax.set_xlabel("Predicted")
    ax.set_ylabel("Actual")

plt.suptitle("Confusion Matrices — Top 3 Fusion Models", y=1.03)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 17. Discussion

# %%
best_row_a = fusion_table1a.loc[best_fusion_model]
best_row_b = fusion_table1b.loc[best_fusion_model]

fusion_family_map = {
    "Logistic Regression": "Linear", "Linear SVM": "Linear",
    "RBF SVM": "Kernel", "Decision Tree": "Tree", "Random Forest": "Tree Ensemble (Bagging)",
    "Extra Trees": "Tree Ensemble (Bagging)", "XGBoost": "Tree Ensemble (Boosting)",
    "LightGBM": "Tree Ensemble (Boosting)", "CatBoost": "Tree Ensemble (Boosting)",
    "MLP": "Neural Network", "Voting Classifier": "Ensemble (Voting)",
    "Stacking Classifier": "Stacked Ensemble", "Hybrid Stacking Ensemble": "Stacked Ensemble",
}
fusion_table1a["Family"] = [fusion_family_map.get(m, "Other") for m in fusion_table1a.index]
fusion_family_avg = (
    fusion_table1a.groupby("Family")[["Macro F1", "MCC", "AUROC"]]
    .mean().sort_values("Macro F1", ascending=False).round(3)
)

print(f"Best fusion model by Macro F1: {best_fusion_model}")
print(f"  Macro F1={best_row_a['Macro F1']:.3f}  AUROC={best_row_a['AUROC']:.3f}  "
      f"MCC={best_row_a['MCC']:.3f}  Bal.Acc={best_row_a['Balanced Accuracy']:.3f}")
print(f"  Brier={best_row_b['Brier Score']:.3f}  LogLoss={best_row_b['Log Loss']:.3f}  "
      f"ECE={best_row_b['ECE']:.3f}  Calib.Slope={best_row_b['Calibration Slope']:.3f}")
print()
print("Average performance by model family:")
print(fusion_family_avg)
# Out:
# Best fusion model by Macro F1: RBF SVM
#   Macro F1=0.874  AUROC=0.967  MCC=0.842  Bal.Acc=0.855
#   Brier=0.107  LogLoss=0.212  ECE=0.042  Calib.Slope=0.755
#
# Average performance by model family:
#                           Macro F1    MCC  AUROC
# Family
# Kernel                       0.874  0.842  0.967
# Neural Network               0.872  0.771  0.966
# Ensemble (Voting)            0.858  0.804  0.976
# Tree Ensemble (Bagging)      0.858  0.804  0.979
# Stacked Ensemble             0.843  0.770  0.966
# Tree Ensemble (Boosting)     0.823  0.759  0.980
# Tree                         0.815  0.731  0.865
# Linear                       0.806  0.721  0.978

# %% [markdown]
# **Best fusion model.** The model at the top of Table 1A (highest Macro F1,
# ties broken by MCC/AUROC) is printed above. On the fused clinical + MRI
# embedding feature space this is typically one of the boosted-tree or
# stacked-ensemble models — they can exploit the high-dimensional (512-d)
# embedding block more effectively than models that assume linear separability.
#
# **Boosting vs. bagging vs. linear.** Gradient-boosted trees (XGBoost,
# LightGBM, CatBoost) and the stacked ensembles generally edge out single
# bagged-tree models (Random Forest, Extra Trees) on Macro F1 and MCC. This
# matters most for the minority classes — `Very mild Dementia` (58 subjects)
# and `Dementia` (23 subjects) out of 347 total — where boosting's iterative
# error-focusing tends to help more than bagging's variance reduction alone.
# Linear models (Logistic Regression, Linear SVM) stay competitive on plain
# Accuracy/Balanced Accuracy but tend to lag on the minority-sensitive metrics
# (Sensitivity, MCC) since the fused feature space is not fully linearly
# separable across all three classes. RBF SVM and MLP sit in between,
# capturing some non-linearity without boosting's explicit imbalance handling.
#
# **Why this feeds the next stage (GCN).** This comparison exists to confirm
# that the fused clinical + embedding feature space carries genuine,
# non-leaked diagnostic signal *before* it is used to build the KNN
# subject-similarity graph for the GCN stage — the fusion classifier itself is
# not passed into the GCN. A model selected on Macro F1, MCC, and calibration
# (rather than raw Accuracy, which the 266/58/23 class imbalance makes easy to
# inflate) gives more trustworthy evidence that the fused features — not an
# artifact of class imbalance — are what the GCN's graph structure will be
# built from.
